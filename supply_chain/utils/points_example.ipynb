# %% [markdown]
# # Generador de puntos
#
# El generador de puntos implementado usa una técnica llamada Poisson Disc Sampling

# %%
from points_generators import poisson_disc_sampling, naive_generator_of_points
import matplotlib.pyplot as plt

points = poisson_disc_sampling(10 + 5 + 5 + 20, (0, 0), (5000, 5000), 20, 20)
plt.scatter([p[0] for p in points], [p[1] for p in points])
print(len(points))
# Out:
# 40

# %%
points = naive_generator_of_points(40, (0,0), (500, 500), 10)
plt.scatter([p[0] for p in points], [p[1] for p in points])
print(len(points))
# Out:
# 40
